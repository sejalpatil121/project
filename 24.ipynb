# %%
import pandas as pd
import numpy as np

# Load the dataset (replace 'forestfires.csv' with your actual file path)
df = pd.read_csv('forestfires.csv')

# Inspect the first few rows to understand the structure
print(df.head())
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
# Create classes for 'area' (region affected)
def classify_area(area):
    if area == 0:
        return 'NotAffected'
    elif 0 < area <= 5:
        return 'PartiallyAffected'
    else:
        return 'MostlyAffected'

# Apply the classification to the 'area' column
df['AffectedClass'] = df['area'].apply(classify_area)

# %%
# Create subsets for each class
not_affected = df[df['AffectedClass'] == 'NotAffected']
partially_affected = df[df['AffectedClass'] == 'PartiallyAffected']
mostly_affected = df[df['AffectedClass'] == 'MostlyAffected']
mostly_affected
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 179  8  6   aug  tue  88.8  147.3  614.5   9.0  14.4  66   5.4   0.0   5.23
# 180  1  3   sep  sun  92.4  124.1  680.7   8.5  23.9  32   6.7   0.0   5.33
# 181  8  6   oct  mon  84.9   32.8  664.2   3.0  19.1  32   4.0   0.0   5.44
# 182  5  4   feb  sun  86.8   15.6   48.3   3.9  12.4  53   2.2   0.0   6.38
# 183  7  4   oct  mon  91.7   48.5  696.1  11.1  16.8  45   4.5   0.0   6.83
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 504  4  3   aug  wed  94.5  139.4  689.1  20.0  28.9  29   4.9   0.0  49.59
# 505  1  2   aug  thu  91.0  163.2  744.4  10.1  26.7  35   1.8   0.0   5.80
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
#
#       AffectedClass
# 179  MostlyAffected
# 180  MostlyAffected
# 181  MostlyAffected
# 182  MostlyAffected
# 183  MostlyAffected
# ..              ...
# 504  MostlyAffected
# 505  MostlyAffected
# 512  MostlyAffected
# 513  MostlyAffected
# 514  MostlyAffected
#
# [151 rows x 14 columns]

# %%
# b. Merge two subsets (NotAffected and PartiallyAffected)
merged_df = pd.concat([not_affected, partially_affected], axis=0)
merged_df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0  0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0  0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0  0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2  0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0  0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...   ...
# 486  5  4   aug  tue  95.1  141.3  605.8  17.7  24.1  43   6.3   0.0  2.00
# 496  4  5   aug  mon  96.2  175.5  661.8  16.8  32.6  26   3.1   0.0  2.77
# 503  2  4   aug  wed  94.5  139.4  689.1  20.0  29.2  30   4.9   0.0  1.95
# 509  5  4   aug  fri  91.0  166.9  752.6   7.1  21.1  71   7.6   1.4  2.17
# 510  6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0  0.43
#
#          AffectedClass
# 0          NotAffected
# 1          NotAffected
# 2          NotAffected
# 3          NotAffected
# 4          NotAffected
# ..                 ...
# 486  PartiallyAffected
# 496  PartiallyAffected
# 503  PartiallyAffected
# 509  PartiallyAffected
# 510  PartiallyAffected
#
# [366 rows x 14 columns]

# %%
# c. Sort Data using Temperature, Wind, RH, and Area
# Ensure that 'temp', 'wind', 'RH', and 'area' columns are numeric (convert if necessary)
df['temp'] = pd.to_numeric(df['temp'], errors='coerce')
df['wind'] = pd.to_numeric(df['wind'], errors='coerce')
df['RH'] = pd.to_numeric(df['RH'], errors='coerce')
df['area'] = pd.to_numeric(df['area'], errors='coerce')

# %%
# Sort by 'temp', 'wind', 'RH', and 'area'
sorted_df = df.sort_values(by=['temp', 'wind', 'RH', 'area'], ascending=[True, True, True, False])
sorted_df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 280  4  6   dec  fri  84.7   26.7  352.6   4.1   2.2  59   4.9   0.0   9.27
# 282  6  3   feb  sun  84.9   27.5  353.5   3.4   4.2  51   4.0   0.0   0.00
# 465  2  2   feb  sat  79.5    3.6   15.3   1.8   4.6  59   0.9   0.0   6.84
# 463  6  5   feb  tue  75.1    4.4   16.2   1.9   4.6  82   6.3   0.0   5.39
# 278  4  4   dec  mon  85.4   25.4  349.7   2.6   4.6  21   8.5   0.0  22.03
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 492  1  3   aug  fri  95.9  158.0  633.6  11.3  32.4  27   2.2   0.0   0.00
# 491  4  4   aug  thu  95.8  152.0  624.1  13.8  32.4  21   4.5   0.0   0.00
# 496  4  5   aug  mon  96.2  175.5  661.8  16.8  32.6  26   3.1   0.0   2.77
# 484  2  5   aug  sun  94.9  130.3  587.1  14.1  33.1  25   4.0   0.0  26.43
# 498  6  5   aug  tue  96.1  181.1  671.2  14.3  33.3  26   2.7   0.0  40.54
#
#          AffectedClass
# 280     MostlyAffected
# 282        NotAffected
# 465     MostlyAffected
# 463     MostlyAffected
# 278     MostlyAffected
# ..                 ...
# 492        NotAffected
# 491        NotAffected
# 496  PartiallyAffected
# 484     MostlyAffected
# 498     MostlyAffected
#
# [517 rows x 14 columns]

# %%
# d. Transposing Data (taking the first 5 rows as an example)
transposed_df = sorted_df.head().transpose()
transposed_df
# Out:
#                           280          282             465             463  \
# X                           4            6               2               6
# Y                           6            3               2               5
# month                     dec          feb             feb             feb
# day                       fri          sun             sat             tue
# FFMC                     84.7         84.9            79.5            75.1
# DMC                      26.7         27.5             3.6             4.4
# DC                      352.6        353.5            15.3            16.2
# ISI                       4.1          3.4             1.8             1.9
# temp                      2.2          4.2             4.6             4.6
# RH                         59           51              59              82
# wind                      4.9          4.0             0.9             6.3
# rain                      0.0          0.0             0.0             0.0
# area                     9.27          0.0            6.84            5.39
# AffectedClass  MostlyAffected  NotAffected  MostlyAffected  MostlyAffected
#
#                           278
# X                           4
# Y                           4
# month                     dec
# day                       mon
# FFMC                     85.4
# DMC                      25.4
# DC                      349.7
# ISI                       2.6
# temp                      4.6
# RH                         21
# wind                      8.5
# rain                      0.0
# area                    22.03
# AffectedClass  MostlyAffected

# %%
# e. Melting Data to long format (example with selected columns)
melted_df = pd.melt(
    df[['month', 'temp', 'wind', 'RH', 'area']],  # Choose relevant columns
    id_vars=['month'],  # Columns that remain unchanged
    var_name='Variable',  # Name for the variable columns
    value_name='Value'  # Name for the values column
)
melted_df
# Out:
#      month Variable  Value
# 0      mar     temp   8.20
# 1      oct     temp  18.00
# 2      oct     temp  14.60
# 3      mar     temp   8.30
# 4      mar     temp  11.40
# ...    ...      ...    ...
# 2063   aug     area   6.44
# 2064   aug     area  54.29
# 2065   aug     area  11.16
# 2066   aug     area   0.00
# 2067   nov     area   0.00
#
# [2068 rows x 3 columns]

# %%
# f. Casting data to wide format (pivoting the melted data)
casted_df = melted_df.pivot_table(
    index='month', 
    columns='Variable', 
    values='Value', 
    aggfunc='mean'  # Use mean or another aggregation function
).reset_index()

casted_df
# Out:
# Variable month         RH       area       temp      wind
# 0          apr  46.888889   8.891111  12.044444  4.666667
# 1          aug  45.489130  12.489076  21.631522  4.086413
# 2          dec  38.444444  13.330000   4.522222  7.644444
# 3          feb  55.700000   6.275000   9.635000  3.755000
# 4          jan  89.000000   0.000000   5.250000  2.000000
# 5          jul  45.125000  14.369687  22.109375  3.734375
# 6          jun  45.117647   5.841176  20.494118  4.135294
# 7          mar  40.000000   4.356667  13.083333  4.968519
# 8          may  67.000000  19.240000  14.650000  4.450000
# 9          nov  31.000000   0.000000  11.800000  4.500000
# 10         oct  37.466667   6.638000  17.093333  3.460000
# 11         sep  42.843023  17.942616  19.612209  3.557558

# %%
# Display the results for all operations
print("\n--- Not Affected Subset ---\n", not_affected.head())
print("\n--- Partially Affected Subset ---\n", partially_affected.head())
print("\n--- Merged Data (NotAffected + PartiallyAffected) ---\n", merged_df.head())
print("\n--- Sorted Data (Temperature, Wind, RH, Area) ---\n", sorted_df[['temp', 'wind', 'RH', 'area']].head())
print("\n--- Transposed Data (First 5 rows) ---\n", transposed_df)
print("\n--- Melted Data (Long Format) ---\n", melted_df.head())
print("\n--- Casted Data (Wide Format) ---\n", casted_df)
# Out:
# --- Not Affected Subset ---
#     X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area  \
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0
#
#   AffectedClass
# 0   NotAffected
# 1   NotAffected
# 2   NotAffected
# 3   NotAffected
# 4   NotAffected
#
# --- Partially Affected Subset ---
#       X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area  \
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0  0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0  0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0  0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0  0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0  0.61
#
#          AffectedClass
# 138  PartiallyAffected
# 139  PartiallyAffected
# 140  PartiallyAffected
# 141  PartiallyAffected
# 142  PartiallyAffected
#
# --- Merged Data (NotAffected + PartiallyAffected) ---
#     X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area  \
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0
#
#   AffectedClass
# 0   NotAffected
# 1   NotAffected
# 2   NotAffected
# 3   NotAffected
# 4   NotAffected
#
# --- Sorted Data (Temperature, Wind, RH, Area) ---
#       temp  wind  RH   area
# 280   2.2   4.9  59   9.27
# 282   4.2   4.0  51   0.00
# 465   4.6   0.9  59   6.84
# 463   4.6   6.3  82   5.39
# 278   4.6   8.5  21  22.03
#
# --- Transposed Data (First 5 rows) ---
#                            280          282             465             463  \
# X                           4            6               2               6
# Y                           6            3               2               5
# month                     dec          feb             feb             feb
# day                       fri          sun             sat             tue
# FFMC                     84.7         84.9            79.5            75.1
# DMC                      26.7         27.5             3.6             4.4
# DC                      352.6        353.5            15.3            16.2
# ISI                       4.1          3.4             1.8             1.9
# temp                      2.2          4.2             4.6             4.6
# RH                         59           51              59              82
# wind                      4.9          4.0             0.9             6.3
# rain                      0.0          0.0             0.0             0.0
# area                     9.27          0.0            6.84            5.39
# AffectedClass  MostlyAffected  NotAffected  MostlyAffected  MostlyAffected
#
#                           278
# X                           4
# Y                           4
# month                     dec
# day                       mon
# FFMC                     85.4
# DMC                      25.4
# DC                      349.7
# ISI                       2.6
# temp                      4.6
# RH                         21
# wind                      8.5
# rain                      0.0
# area                    22.03
# AffectedClass  MostlyAffected
#
# --- Melted Data (Long Format) ---
#    month Variable  Value
# 0   mar     temp    8.2
# 1   oct     temp   18.0
# 2   oct     temp   14.6
# 3   mar     temp    8.3
# 4   mar     temp   11.4
#
# --- Casted Data (Wide Format) ---
#  Variable month         RH       area       temp      wind
# 0          apr  46.888889   8.891111  12.044444  4.666667
# 1          aug  45.489130  12.489076  21.631522  4.086413
# 2          dec  38.444444  13.330000   4.522222  7.644444
# 3          feb  55.700000   6.275000   9.635000  3.755000
# 4          jan  89.000000   0.000000   5.250000  2.000000
# 5          jul  45.125000  14.369687  22.109375  3.734375
# 6          jun  45.117647   5.841176  20.494118  4.135294
# 7          mar  40.000000   4.356667  13.083333  4.968519
# 8          may  67.000000  19.240000  14.650000  4.450000
# 9          nov  31.000000   0.000000  11.800000  4.500000
# 10         oct  37.466667   6.638000  17.093333  3.460000
# 11         sep  42.843023  17.942616  19.612209  3.557558
